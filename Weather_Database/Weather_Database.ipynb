# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | nouadhibou
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | hot springs
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | cayenne
# Processing Record 10 of Set 1 | porto novo
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | lae
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | lesosibirsk
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | kapchorwa
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | maniitsoq
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | gwadar
# Processing Record 27 of Set 1 | kavarna
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | sztum
# Processing Record 31 of Set 1 | tahe
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | samarai
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | shache
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | arica
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | katsuura
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | vavuniya
# Processing Record 1 of Set 2 | hampton
# Processing Record 2 of Set 2 | fukue
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | ancud
# Processing Record 6 of Set 2 | nuuk
# Processing Record 7 of Set 2 | ternate
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | puyo
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | manavalakurichi
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | sinnamary
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | vodnyy
# Processing Record 23 of Set 2 | deputatskiy
# Processing Record 24 of Set 2 | yangambi
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | urucui
# Processing Record 27 of Set 2 | katangi
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | henzada
# City not found. Skipping...
# Processing Record 31 of Set 2 | mayahi
# Processing Record 32 of Set 2 | chupa
# Processing Record 33 of Set 2 | muros
# Processing Record 34 of Set 2 | lorengau
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | yarmouth
# Processing Record 37 of Set 2 | sambava
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | thaba nchu
# Processing Record 40 of Set 2 | markova
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | toora-khem
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | bathsheba
# Processing Record 46 of Set 2 | bodo
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | owando
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | tongliao
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | pisco
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | presidencia roque saenz pena
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | zhigansk
# Processing Record 12 of Set 3 | dali
# Processing Record 13 of Set 3 | santa cruz
# Processing Record 14 of Set 3 | le port
# Processing Record 15 of Set 3 | rancho palos verdes
# Processing Record 16 of Set 3 | busselton
# Processing Record 17 of Set 3 | votorantim
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | ahipara
# Processing Record 20 of Set 3 | mingaora
# Processing Record 21 of Set 3 | stilfontein
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | macenta
# Processing Record 24 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 3 | astoria
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | mogok
# Processing Record 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | abu zabad
# Processing Record 31 of Set 3 | santo antonio do monte
# Processing Record 32 of Set 3 | kurumkan
# Processing Record 33 of Set 3 | antofagasta
# Processing Record 34 of Set 3 | nabire
# Processing Record 35 of Set 3 | ambon
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | port alfred
# Processing Record 38 of Set 3 | lulea
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | ilulissat
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | shingu
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | puerto escondido
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | tabarqah
# City not found. Skipping...
# Processing Record 47 of Set 3 | jinxiang
# Processing Record 48 of Set 3 | houma
# Processing Record 49 of Set 3 | marzuq
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | claremore
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | kachiry
# Processing Record 4 of Set 4 | sitarganj
# Processing Record 5 of Set 4 | korla
# Processing Record 6 of Set 4 | angol
# Processing Record 7 of Set 4 | caboolture
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | merrill
# Processing Record 10 of Set 4 | macau
# Processing Record 11 of Set 4 | two rivers
# Processing Record 12 of Set 4 | shalya
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | dharchula
# Processing Record 15 of Set 4 | hakvik
# City not found. Skipping...
# Processing Record 16 of Set 4 | masuguru
# Processing Record 17 of Set 4 | tikhmenevo
# City not found. Skipping...
# Processing Record 18 of Set 4 | baykit
# Processing Record 19 of Set 4 | bayir
# Processing Record 20 of Set 4 | austin
# Processing Record 21 of Set 4 | chenzhou
# Processing Record 22 of Set 4 | oriximina
# Processing Record 23 of Set 4 | boyolangu
# Processing Record 24 of Set 4 | gayny
# Processing Record 25 of Set 4 | kokoda
# Processing Record 26 of Set 4 | erdenet
# Processing Record 27 of Set 4 | mosquera
# Processing Record 28 of Set 4 | adwa
# Processing Record 29 of Set 4 | airai
# Processing Record 30 of Set 4 | huarmey
# Processing Record 31 of Set 4 | san ramon
# Processing Record 32 of Set 4 | esfarayen
# Processing Record 33 of Set 4 | bilibino
# Processing Record 34 of Set 4 | store heddinge
# Processing Record 35 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 4 | pacifica
# Processing Record 37 of Set 4 | riyadh
# Processing Record 38 of Set 4 | san patricio
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 41 of Set 4 | matara
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | tripoli
# Processing Record 44 of Set 4 | jalu
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | lujiang
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | sakakah
# Processing Record 50 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 5 | sungairaya
# Processing Record 2 of Set 5 | kerema
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | sangar
# Processing Record 5 of Set 5 | barao de melgaco
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | northam
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | baghdad
# Processing Record 11 of Set 5 | panguna
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | cedar lake
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | fort abbas
# Processing Record 16 of Set 5 | cedar falls
# Processing Record 17 of Set 5 | hillsborough
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | kangaatsiaq
# Processing Record 20 of Set 5 | renfrew
# Processing Record 21 of Set 5 | yellowknife
# Processing Record 22 of Set 5 | sao filipe
# Processing Record 23 of Set 5 | maldonado
# Processing Record 24 of Set 5 | hirara
# Processing Record 25 of Set 5 | kodiak
# Processing Record 26 of Set 5 | pemangkat
# Processing Record 27 of Set 5 | hokitika
# Processing Record 28 of Set 5 | ayr
# Processing Record 29 of Set 5 | kizema
# Processing Record 30 of Set 5 | kirakira
# Processing Record 31 of Set 5 | nizwa
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | north bend
# Processing Record 34 of Set 5 | coahuayana
# Processing Record 35 of Set 5 | lusambo
# Processing Record 36 of Set 5 | manta
# Processing Record 37 of Set 5 | tocopilla
# Processing Record 38 of Set 5 | kaeo
# Processing Record 39 of Set 5 | tungor
# Processing Record 40 of Set 5 | tasiilaq
# Processing Record 41 of Set 5 | castro
# Processing Record 42 of Set 5 | sorland
# Processing Record 43 of Set 5 | praia
# Processing Record 44 of Set 5 | vanimo
# Processing Record 45 of Set 5 | pangody
# Processing Record 46 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | talara
# Processing Record 49 of Set 5 | lavumisa
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | harper
# Processing Record 2 of Set 6 | bambanglipuro
# Processing Record 3 of Set 6 | scarborough
# Processing Record 4 of Set 6 | mandi bahauddin
# Processing Record 5 of Set 6 | emba
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | pacific grove
# Processing Record 8 of Set 6 | sao luiz gonzaga
# Processing Record 9 of Set 6 | kapurthala
# Processing Record 10 of Set 6 | platteville
# Processing Record 11 of Set 6 | vao
# Processing Record 12 of Set 6 | port hawkesbury
# Processing Record 13 of Set 6 | pronsk
# Processing Record 14 of Set 6 | karratha
# Processing Record 15 of Set 6 | kulhudhuffushi
# Processing Record 16 of Set 6 | rabaul
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | hasaki
# Processing Record 19 of Set 6 | viedma
# Processing Record 20 of Set 6 | saint-louis
# Processing Record 21 of Set 6 | pingliang
# Processing Record 22 of Set 6 | whitianga
# Processing Record 23 of Set 6 | cabo san lucas
# Processing Record 24 of Set 6 | kumukh
# Processing Record 25 of Set 6 | gabu
# Processing Record 26 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 6 | beyneu
# Processing Record 28 of Set 6 | guerrero negro
# Processing Record 29 of Set 6 | kondoa
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | tilichiki
# Processing Record 33 of Set 6 | hovd
# Processing Record 34 of Set 6 | zaysan
# Processing Record 35 of Set 6 | bontang
# Processing Record 36 of Set 6 | wau
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | puerto ayora
# Processing Record 39 of Set 6 | takoradi
# Processing Record 40 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 6 | gambela
# Processing Record 42 of Set 6 | alice springs
# Processing Record 43 of Set 6 | oksfjord
# Processing Record 44 of Set 6 | mithi
# Processing Record 45 of Set 6 | ulladulla
# Processing Record 46 of Set 6 | limbang
# Processing Record 47 of Set 6 | ullapool
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | hami
# Processing Record 50 of Set 6 | isangel
# Processing Record 1 of Set 7 | gornopravdinsk
# Processing Record 2 of Set 7 | acarau
# Processing Record 3 of Set 7 | desbiens
# Processing Record 4 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 7 | sisimiut
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | aksu
# Processing Record 8 of Set 7 | college
# Processing Record 9 of Set 7 | coos bay
# Processing Record 10 of Set 7 | zhangzhou
# Processing Record 11 of Set 7 | tayshet
# Processing Record 12 of Set 7 | panaba
# Processing Record 13 of Set 7 | south sioux city
# Processing Record 14 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 7 | bonthe
# Processing Record 17 of Set 7 | halifax
# Processing Record 18 of Set 7 | redlands
# Processing Record 19 of Set 7 | sibolga
# Processing Record 20 of Set 7 | matina
# Processing Record 21 of Set 7 | qiongshan
# Processing Record 22 of Set 7 | oranjestad
# Processing Record 23 of Set 7 | daru
# Processing Record 24 of Set 7 | nelson bay
# Processing Record 25 of Set 7 | chokurdakh
# Processing Record 26 of Set 7 | chara
# Processing Record 27 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 7 | beringovskiy
# Processing Record 29 of Set 7 | mahanoro
# Processing Record 30 of Set 7 | batsfjord
# Processing Record 31 of Set 7 | gzhatsk
# City not found. Skipping...
# Processing Record 32 of Set 7 | masindi
# Processing Record 33 of Set 7 | hofn
# Processing Record 34 of Set 7 | beloha
# Processing Record 35 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 7 | waipawa
# Processing Record 37 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 7 | plettenberg bay
# Processing Record 39 of Set 7 | salym
# Processing Record 40 of Set 7 | padang
# Processing Record 41 of Set 7 | tazovskiy
# Processing Record 42 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 7 | adrar
# Processing Record 44 of Set 7 | raver
# Processing Record 45 of Set 7 | caravelas
# Processing Record 46 of Set 7 | kaspiysk
# Processing Record 47 of Set 7 | gainesville
# Processing Record 48 of Set 7 | umm lajj
# Processing Record 49 of Set 7 | husavik
# Processing Record 50 of Set 7 | anshun
# Processing Record 1 of Set 8 | marienburg
# Processing Record 2 of Set 8 | eyl
# Processing Record 3 of Set 8 | klaksvik
# Processing Record 4 of Set 8 | keta
# Processing Record 5 of Set 8 | manjacaze
# Processing Record 6 of Set 8 | aasiaat
# Processing Record 7 of Set 8 | antalaha
# Processing Record 8 of Set 8 | axim
# Processing Record 9 of Set 8 | lukulu
# Processing Record 10 of Set 8 | gizo
# Processing Record 11 of Set 8 | meadow lake
# Processing Record 12 of Set 8 | palauig
# Processing Record 13 of Set 8 | ulmeni
# Processing Record 14 of Set 8 | morogoro
# Processing Record 15 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | waraseoni
# Processing Record 19 of Set 8 | smolenka
# Processing Record 20 of Set 8 | yumen
# Processing Record 21 of Set 8 | dunedin
# Processing Record 22 of Set 8 | prince rupert
# Processing Record 23 of Set 8 | hamina
# Processing Record 24 of Set 8 | sao joao da barra
# Processing Record 25 of Set 8 | cairns
# Processing Record 26 of Set 8 | meiganga
# Processing Record 27 of Set 8 | gimli
# Processing Record 28 of Set 8 | lavrentiya
# Processing Record 29 of Set 8 | skegness
# Processing Record 30 of Set 8 | gonen
# Processing Record 31 of Set 8 | kostomuksha
# Processing Record 32 of Set 8 | high level
# Processing Record 33 of Set 8 | ramsar
# Processing Record 34 of Set 8 | bam
# Processing Record 35 of Set 8 | katobu
# Processing Record 36 of Set 8 | acara
# Processing Record 37 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 8 | havre-saint-pierre
# Processing Record 39 of Set 8 | kahului
# Processing Record 40 of Set 8 | khabary
# Processing Record 41 of Set 8 | grindavik
# Processing Record 42 of Set 8 | luderitz
# Processing Record 43 of Set 8 | nome
# Processing Record 44 of Set 8 | louis trichardt
# Processing Record 45 of Set 8 | santa maria da vitoria
# Processing Record 46 of Set 8 | quesnel
# Processing Record 47 of Set 8 | hobyo
# Processing Record 48 of Set 8 | palmer
# Processing Record 49 of Set 8 | laguna
# Processing Record 50 of Set 8 | sydney mines
# Processing Record 1 of Set 9 | ixtapa
# Processing Record 2 of Set 9 | namibe
# Processing Record 3 of Set 9 | moerai
# Processing Record 4 of Set 9 | mitsamiouli
# Processing Record 5 of Set 9 | alta floresta
# Processing Record 6 of Set 9 | lagoa
# Processing Record 7 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | aljezur
# Processing Record 10 of Set 9 | maceio
# Processing Record 11 of Set 9 | faya
# Processing Record 12 of Set 9 | nizhniy baskunchak
# Processing Record 13 of Set 9 | dobson
# Processing Record 14 of Set 9 | stornoway
# Processing Record 15 of Set 9 | magnitogorsk
# Processing Record 16 of Set 9 | lubango
# Processing Record 17 of Set 9 | kidal
# Processing Record 18 of Set 9 | ismailia
# Processing Record 19 of Set 9 | kang
# Processing Record 20 of Set 9 | chabahar
# Processing Record 21 of Set 9 | ongandjera
# Processing Record 22 of Set 9 | shakawe
# Processing Record 23 of Set 9 | cidreira
# Processing Record 24 of Set 9 | emerald
# Processing Record 25 of Set 9 | kazachinskoye
# Processing Record 26 of Set 9 | saint-georges
# Processing Record 27 of Set 9 | eureka
# Processing Record 28 of Set 9 | alghero
# Processing Record 29 of Set 9 | taksimo
# Processing Record 30 of Set 9 | coihaique
# Processing Record 31 of Set 9 | sao felix do xingu
# Processing Record 32 of Set 9 | saint anthony
# Processing Record 33 of Set 9 | svetlogorsk
# Processing Record 34 of Set 9 | nicoya
# Processing Record 35 of Set 9 | marathon
# Processing Record 36 of Set 9 | kosiv
# Processing Record 37 of Set 9 | san andres
# Processing Record 38 of Set 9 | hirado
# Processing Record 39 of Set 9 | matane
# Processing Record 40 of Set 9 | rodeo
# Processing Record 41 of Set 9 | oron
# Processing Record 42 of Set 9 | sarangani
# Processing Record 43 of Set 9 | santa isabel
# Processing Record 44 of Set 9 | martapura
# Processing Record 45 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 9 | carutapera
# Processing Record 47 of Set 9 | berlevag
# Processing Record 48 of Set 9 | wanxian
# Processing Record 49 of Set 9 | udachnyy
# Processing Record 50 of Set 9 | sioux lookout
# Processing Record 1 of Set 10 | nara
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | saint-joseph
# Processing Record 4 of Set 10 | russell
# Processing Record 5 of Set 10 | bajil
# Processing Record 6 of Set 10 | mount isa
# Processing Record 7 of Set 10 | shimoda
# Processing Record 8 of Set 10 | sao miguel do araguaia
# Processing Record 9 of Set 10 | vaitape
# Processing Record 10 of Set 10 | changde
# Processing Record 11 of Set 10 | leh
# Processing Record 12 of Set 10 | kingman
# Processing Record 13 of Set 10 | geraldton
# Processing Record 14 of Set 10 | kuusamo
# Processing Record 15 of Set 10 | itarema
# Processing Record 16 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 10 | nurota
# Processing Record 18 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 10 | puerto carreno
# Processing Record 20 of Set 10 | nakusp
# Processing Record 21 of Set 10 | komsomolskiy
# Processing Record 22 of Set 10 | labangan
# Processing Record 23 of Set 10 | safaga
# Processing Record 24 of Set 10 | visnes
# Processing Record 25 of Set 10 | smederevska palanka
# Processing Record 26 of Set 10 | romitan
# Processing Record 27 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 10 | gladstone
# Processing Record 30 of Set 10 | teya
# Processing Record 31 of Set 10 | belaya gora
# Processing Record 32 of Set 10 | cacequi
# Processing Record 33 of Set 10 | tournon-sur-rhone
# Processing Record 34 of Set 10 | moose factory
# Processing Record 35 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 10 | kruisfontein
# Processing Record 37 of Set 10 | andenes
# Processing Record 38 of Set 10 | lerwick
# Processing Record 39 of Set 10 | port blair
# Processing Record 40 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | taonan
# Processing Record 42 of Set 10 | coquimbo
# Processing Record 43 of Set 10 | baft
# Processing Record 44 of Set 10 | chadiza
# Processing Record 45 of Set 10 | marshall
# Processing Record 46 of Set 10 | sola
# Processing Record 47 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 10 | weston
# Processing Record 49 of Set 10 | kenai
# Processing Record 50 of Set 10 | yerbogachen
# Processing Record 1 of Set 11 | malatya
# Processing Record 2 of Set 11 | sapa
# Processing Record 3 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 11 | canutama
# Processing Record 6 of Set 11 | anjiang
# Processing Record 7 of Set 11 | saint-pierre
# Processing Record 8 of Set 11 | katherine
# Processing Record 9 of Set 11 | bandarbeyla
# Processing Record 10 of Set 11 | talnakh
# Processing Record 11 of Set 11 | nueve de julio
# Processing Record 12 of Set 11 | chegdomyn
# Processing Record 13 of Set 11 | phalaborwa
# Processing Record 14 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 15 of Set 11 | hongjiang
# Processing Record 16 of Set 11 | boguchany
# Processing Record 17 of Set 11 | bitung
# Processing Record 18 of Set 11 | juneau
# Processing Record 19 of Set 11 | kempele
# Processing Record 20 of Set 11 | zhifang
# Processing Record 21 of Set 11 | agadez
# Processing Record 22 of Set 11 | galich
# Processing Record 23 of Set 11 | sobolevo
# Processing Record 24 of Set 11 | hanyang
# Processing Record 25 of Set 11 | labuan
# Processing Record 26 of Set 11 | hearst
# Processing Record 27 of Set 11 | grenville
# Processing Record 28 of Set 11 | half moon bay
# Processing Record 29 of Set 11 | shu
# Processing Record 30 of Set 11 | oltu
# Processing Record 31 of Set 11 | filiatra
# Processing Record 32 of Set 11 | roald
# Processing Record 33 of Set 11 | westport
# Processing Record 34 of Set 11 | kushiro
# Processing Record 35 of Set 11 | aleksandrov gay
# Processing Record 36 of Set 11 | boralday
# Processing Record 37 of Set 11 | erzin
# Processing Record 38 of Set 11 | amurrio
# Processing Record 39 of Set 11 | myaundzha
# Processing Record 40 of Set 11 | rio gallegos
# Processing Record 41 of Set 11 | bonavista
# Processing Record 42 of Set 11 | venado tuerto
# Processing Record 43 of Set 11 | nazare
# Processing Record 44 of Set 11 | aswan
# Processing Record 45 of Set 11 | waingapu
# Processing Record 46 of Set 11 | fare
# Processing Record 47 of Set 11 | tiznit
# Processing Record 48 of Set 11 | teeli
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 50 of Set 11 | malayal
# Processing Record 1 of Set 12 | jaicos
# Processing Record 2 of Set 12 | ostersund
# Processing Record 3 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 12 | san cristobal
# Processing Record 5 of Set 12 | burica
# City not found. Skipping...
# Processing Record 6 of Set 12 | lakota
# Processing Record 7 of Set 12 | nichinan
# Processing Record 8 of Set 12 | grand-santi
# Processing Record 9 of Set 12 | koslan
# Processing Record 10 of Set 12 | garmsar
# Processing Record 11 of Set 12 | manzhouli
# Processing Record 12 of Set 12 | mongagua
# Processing Record 13 of Set 12 | nisia floresta
# Processing Record 14 of Set 12 | mutoko
# Processing Record 15 of Set 12 | marawi
# Processing Record 16 of Set 12 | lahaina
# Processing Record 17 of Set 12 | sakaiminato
# Processing Record 18 of Set 12 | mattru
# Processing Record 19 of Set 12 | omaruru
# Processing Record 20 of Set 12 | sidvokodvo
# Processing Record 21 of Set 12 | guozhen
# Processing Record 22 of Set 12 | sawai madhopur
# Processing Record 23 of Set 12 | anloga
# Processing Record 24 of Set 12 | kailua
# Processing Record 25 of Set 12 | raga
# Processing Record 26 of Set 12 | manono
# Processing Record 27 of Set 12 | sacramento
# Processing Record 28 of Set 12 | cascais
# Processing Record 29 of Set 12 | el quetzal
# Processing Record 30 of Set 12 | chacarita
# Processing Record 31 of Set 12 | sulangan
# Processing Record 32 of Set 12 | savonlinna
# Processing Record 33 of Set 12 | cururupu
# Processing Record 34 of Set 12 | tiarei
# Processing Record 35 of Set 12 | xining
# Processing Record 36 of Set 12 | pangkalanbuun
# Processing Record 37 of Set 12 | fairbanks
# Processing Record 38 of Set 12 | villazon
# Processing Record 39 of Set 12 | biryukove
# Processing Record 40 of Set 12 | torrox
# Processing Record 41 of Set 12 | luanda
# Processing Record 42 of Set 12 | port-cartier
# Processing Record 43 of Set 12 | honningsvag
# Processing Record 44 of Set 12 | novoagansk
# Processing Record 45 of Set 12 | santa catarina de tepehuanes
# Processing Record 46 of Set 12 | vostochnyy
# Processing Record 47 of Set 12 | dandong
# Processing Record 48 of Set 12 | dargaville
# Processing Record 49 of Set 12 | san jose
# Processing Record 50 of Set 12 | piacabucu
# Processing Record 1 of Set 13 | bani
# Processing Record 2 of Set 13 | kysyl-syr
# Processing Record 3 of Set 13 | sorong
# Processing Record 4 of Set 13 | yanam
# Processing Record 5 of Set 13 | broome
# Processing Record 6 of Set 13 | camopi
# Processing Record 7 of Set 13 | mayya
# Processing Record 8 of Set 13 | leshukonskoye
# Processing Record 9 of Set 13 | nantucket
# Processing Record 10 of Set 13 | goma
# Processing Record 11 of Set 13 | kloulklubed
# Processing Record 12 of Set 13 | kribi
# Processing Record 13 of Set 13 | muzhi
# Processing Record 14 of Set 13 | murree
# Processing Record 15 of Set 13 | santiago
# Processing Record 16 of Set 13 | astipalaia
# City not found. Skipping...
# Processing Record 17 of Set 13 | camacha
# Processing Record 18 of Set 13 | qaqortoq
# Processing Record 19 of Set 13 | solton
# Processing Record 20 of Set 13 | ende
# Processing Record 21 of Set 13 | shaunavon
# Processing Record 22 of Set 13 | san carlos de bariloche
# Processing Record 23 of Set 13 | charters towers
# Processing Record 24 of Set 13 | cabra
# Processing Record 25 of Set 13 | kyzyl-suu
# Processing Record 26 of Set 13 | krasnoselkup
# Processing Record 27 of Set 13 | orange cove
# Processing Record 28 of Set 13 | pangnirtung
# Processing Record 29 of Set 13 | redmond
# Processing Record 30 of Set 13 | inta
# Processing Record 31 of Set 13 | sabang
# Processing Record 32 of Set 13 | namalenga
# Processing Record 33 of Set 13 | vadso
# Processing Record 34 of Set 13 | acari
# Processing Record 35 of Set 13 | lazaro cardenas
# Processing Record 36 of Set 13 | hualmay
# Processing Record 37 of Set 13 | portland
# Processing Record 38 of Set 13 | uberaba
# Processing Record 39 of Set 13 | tupik
# Processing Record 40 of Set 13 | maumere
# Processing Record 41 of Set 13 | teguldet
# Processing Record 42 of Set 13 | thoen
# Processing Record 43 of Set 13 | moissala
# Processing Record 44 of Set 13 | conde
# Processing Record 45 of Set 13 | miramar
# Processing Record 46 of Set 13 | roebourne
# Processing Record 47 of Set 13 | ibra
# Processing Record 48 of Set 13 | akonolinga
# Processing Record 49 of Set 13 | nyazepetrovsk
# Processing Record 50 of Set 13 | vestmannaeyjar
# Processing Record 1 of Set 14 | mehamn
# Processing Record 2 of Set 14 | marsa matruh
# Processing Record 3 of Set 14 | ndende
# Processing Record 4 of Set 14 | vredendal
# Processing Record 5 of Set 14 | tatarsk
# Processing Record 6 of Set 14 | mengcheng
# Processing Record 7 of Set 14 | manokwari
# Processing Record 8 of Set 14 | maragogi
# Processing Record 9 of Set 14 | hinton
# Processing Record 10 of Set 14 | eenhana
# Processing Record 11 of Set 14 | supe
# Processing Record 12 of Set 14 | robertsport
# Processing Record 13 of Set 14 | pervomayskoye
# Processing Record 14 of Set 14 | pauini
# Processing Record 15 of Set 14 | spartanburg
# Processing Record 16 of Set 14 | priiskovyy
# Processing Record 17 of Set 14 | kununurra
# Processing Record 18 of Set 14 | nieuw amsterdam
# Processing Record 19 of Set 14 | biltine
# Processing Record 20 of Set 14 | henties bay
# Processing Record 21 of Set 14 | dawlatabad
# Processing Record 22 of Set 14 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 14 | netarhat
# Processing Record 24 of Set 14 | surt
# Processing Record 25 of Set 14 | chihuahua
# Processing Record 26 of Set 14 | porto velho
# Processing Record 27 of Set 14 | omsukchan
# Processing Record 28 of Set 14 | salinopolis
# Processing Record 29 of Set 14 | laval
# Processing Record 30 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 14 | vila
# Processing Record 32 of Set 14 | irtyshskiy
# Processing Record 33 of Set 14 | gaoua
# Processing Record 34 of Set 14 | gogrial
# Processing Record 35 of Set 14 | misratah
# Processing Record 36 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 14 | inhambane
# Processing Record 38 of Set 14 | broken hill
# Processing Record 39 of Set 14 | tessalit
# Processing Record 40 of Set 14 | kalabo
# Processing Record 41 of Set 14 | penzance
# Processing Record 42 of Set 14 | mnogovershinnyy
# Processing Record 43 of Set 14 | luganville
# Processing Record 44 of Set 14 | tumut
# Processing Record 45 of Set 14 | abha
# Processing Record 46 of Set 14 | gillette
# Processing Record 47 of Set 14 | beira
# Processing Record 48 of Set 14 | delta del tigre
# Processing Record 49 of Set 14 | smidovich
# Processing Record 50 of Set 14 | jacareacanga
# Processing Record 1 of Set 15 | chinsali
# Processing Record 2 of Set 15 | de-kastri
# Processing Record 3 of Set 15 | birao
# Processing Record 4 of Set 15 | iskateley
# Processing Record 5 of Set 15 | namatanai
# Processing Record 6 of Set 15 | the valley
# Processing Record 7 of Set 15 | herat
# Processing Record 8 of Set 15 | nemuro
# Processing Record 9 of Set 15 | linkoping
# Processing Record 10 of Set 15 | jucurutu
# Processing Record 11 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 15 | hostotipaquillo
# Processing Record 13 of Set 15 | yarega
# Processing Record 14 of Set 15 | simpang
# Processing Record 15 of Set 15 | tsaratanana
# Processing Record 16 of Set 15 | annau
# Processing Record 17 of Set 15 | omboue
# Processing Record 18 of Set 15 | suntar
# Processing Record 19 of Set 15 | segou
# Processing Record 20 of Set 15 | muravlenko
# Processing Record 21 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 15 | rio claro
# Processing Record 23 of Set 15 | aguada de pasajeros
# Processing Record 24 of Set 15 | balkanabat
# Processing Record 25 of Set 15 | richmond
# Processing Record 26 of Set 15 | srednekolymsk
# Processing Record 27 of Set 15 | rock springs
# Processing Record 28 of Set 15 | chicama
# Processing Record 29 of Set 15 | nyurba
# Processing Record 30 of Set 15 | krasnyy yar
# Processing Record 31 of Set 15 | tommot
# Processing Record 32 of Set 15 | reyes
# Processing Record 33 of Set 15 | asau
# Processing Record 34 of Set 15 | galesong
# Processing Record 35 of Set 15 | taoudenni
# Processing Record 36 of Set 15 | soure
# Processing Record 37 of Set 15 | mackay
# Processing Record 38 of Set 15 | richards bay
# Processing Record 39 of Set 15 | stekolnyy
# City not found. Skipping...
# Processing Record 40 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 15 | flinders
# Processing Record 42 of Set 15 | lufilufi
# Processing Record 43 of Set 15 | alice town
# Processing Record 44 of Set 15 | okha
# Processing Record 45 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 15 | parainen
# Processing Record 47 of Set 15 | sattahip
# Processing Record 48 of Set 15 | pierre
# Processing Record 49 of Set 15 | sikasso
# Processing Record 50 of Set 15 | bouna
# Processing Record 1 of Set 16 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 16 | port-de-bouc
# Processing Record 3 of Set 16 | yarada
# Processing Record 4 of Set 16 | tual
# Processing Record 5 of Set 16 | acapulco
# Processing Record 6 of Set 16 | guiratinga
# Processing Record 7 of Set 16 | oranjemund
# Processing Record 8 of Set 16 | mandalgovi
# Processing Record 9 of Set 16 | teguise
# Processing Record 10 of Set 16 | bukene
# Processing Record 11 of Set 16 | mount gambier
# Processing Record 12 of Set 16 | stettler
# Processing Record 13 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 16 | tairua
# Processing Record 15 of Set 16 | tenali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# New column order
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0  Arraial Do Cabo      BR  2022-09-06 04:37:42 -22.9661  -42.0278     66.25
# 1       Nouadhibou      MR  2022-09-06 04:42:28  20.9310  -17.0347     75.18
# 2     Punta Arenas      CL  2022-09-06 04:42:28 -53.1500  -70.9167     33.91
# 3      Hot Springs      US  2022-09-06 04:42:29  34.5037  -93.0552     72.72
# 4         Saldanha      ZA  2022-09-06 04:42:29 -33.0117   17.9442     48.25
# 5      Provideniya      RU  2022-09-06 04:42:29  64.3833 -173.3000     48.36
# 6          Cayenne      GF  2022-09-06 04:42:30   4.9333  -52.3333     77.04
# 7       Porto Novo      BJ  2022-09-06 04:42:30   6.4965    2.6036     75.02
# 8     Saint George      US  2022-09-06 04:42:30  37.1041 -113.5841     97.39
# 9              Lae      PG  2022-09-06 04:42:31  -6.7221  146.9847     92.07
#
#    Humidity  Cloudiness  Wind Speed          Current Description
# 0        65          88       11.99              overcast clouds
# 1        78           0       11.50                    clear sky
# 2        86          40       20.71  light intensity shower rain
# 3        90         100        3.00              overcast clouds
# 4        80           7        5.44                    clear sky
# 5        93         100        8.95  light intensity shower rain
# 6        94          96        0.00              overcast clouds
# 7        93          51        4.90                broken clouds
# 8        19           0        3.44                    clear sky
# 9        66          98        8.08              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
